# %% [markdown]
# # Reverse Engineering At-Bay Calculator
#
# The goal here is to work backwards trying to figure out how this calculator works. I began by looking at the source, which leads to a minified javascript code. Beautifying and looking at the javascript code shows that the calculations are done on the server-side, so I won't be able to figure it out from viewing the code.
#
# The next thing I tried was looking at the code in burp suite. This shows the website is submitting the following request:

# %% [markdown]
# `
# GET /bp/api/gui/v1/financial_exposure/calculate?record_owner=customer_and_employee&num_records=92000&record_type=PHI-PCI&breach_type=error&percent_addr_stored=0&recent_breach=true&network_complexity=low&public_profile=large&security_quality=below&ca_based=true HTTP/1.1
# Host: www.at-bay.com
# Connection: close
# Accept: application/json, text/javascript, */*; q=0.01
# DNT: 1
# X-Requested-With: XMLHttpRequest
# User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36
# Content-Type: application/json
# Referer: https://www.at-bay.com/data-breach-calculator/
# Accept-Encoding: gzip, deflate
# Accept-Language: en-US,en;q=0.9
# Cookie: visid_incap_1608995=1x8GWrW/SBKSl9YR0xz+9yq4AVwAAAAAQUIPAAAAAAD5DjHpx8LIceWTb6lRzS1B; _ga=GA1.2.648618893.1543616556; __insp_uid=3545768712; __insp_wid=1575031163; __insp_nv=false; __insp_targlpu=aHR0cHM6Ly93d3cuYXQtYmF5LmNvbS9kYXRhLWJyZWFjaC1jYWxjdWxhdG9yLw%3D%3D; __insp_targlpt=RGF0YSBCcmVhY2ggQ29zdCBDYWxjdWxhdG9y; __insp_sid=1800059517; incap_ses_982_1608995=0TaFNrzHM08gN7/RUMSgDRlRJVwAAAAA8EkB/bP5I2xDhzzD7g3VjA==; incap_ses_976_1608995=/OR4fR/Kr1H+U/uhVnOLDSZRJVwAAAAAaUkY57OsB21J1atz4q5kzQ==; incap_ses_981_1608995=XlalGKgvqTmLlv2d1DadDZp8JVwAAAAAFTuXMCruMiw3s2m80hmdMA==; _gid=GA1.2.168275885.1546380482; incap_ses_444_1608995=4J5rJDY+aAeE2nGH1GgpBsHkK1wAAAAAc3CNWkWXT/eHas0k3gyf9w==; __insp_pad=3; __insp_slim=1546380711791
# `

# %% [markdown]
# Which results in the following response:

# %% [markdown]
# `HTTP/1.1 200 OK
# Server: nginx
# Date: Tue, 01 Jan 2019 22:12:43 GMT
# Content-Type: application/json
# Content-Length: 321
# Connection: close
# Strict-Transport-Security: max-age=31536000;
# X-Iinfo: 4-172892599-172892604 NNNN CT(37 37 0) RT(1546380763664 20) q(0 0 1 -1) r(2 2) U5
# X-CDN: Incapsula
#
# {"result": {"breach_coach": 25000, "call_center": 66000, "class_action_fines_and_defense": 5400000, "credit_monitoring": 120000, "crisis_management": 100000, "forensics": 90000, "notification": 2800, "pci_fines": 2800000, "regulatory_fines_and_defense": 6600000}, "total": 15203800, "cost_per_record": 165.2586956521739}`

# %% [markdown]
# This will show me all the information that I need to know. The url `/bp/api/gui/v1/financial_exposure/calculate?record_owner=customer_and_employee&num_records=92000&record_type=PHI-PCI&breach_type=error&percent_addr_stored=100&recent_breach=true&network_complexity=high&public_profile=large&security_quality=above&ca_based=true
# ` in the request shows that the variables we need to modify are `record_owner, num_records, record_type, breach_type, percent_addr_stored, recent_breach, network_complexity, public_profile, security_quality, and ca_based`, corresponding to the questions in the order they are asked on the calculator.
#
# Through looking at the requests sent when changing values, we can see that the possible values for each of these are:
#
# `record_owner: employee_only, customer_and_employee
# num_records: 1-100000000
# record_type: PII, PHI, PCI, PCI-PHI
# breach_type: error, theft, hack
# percent_addr_stored: 0-100
# recent_breach: true, false
# network_complexity: low, medium, high
# public_profile: small, medium, large
# security_quality: below, average, above
# ca_based: true, false`

# %%
import urllib3
from bs4 import BeautifulSoup


rolist = ['employee_only', 'customer_and_employee']
nrlist = [1, 10000, 100000000]
rtlist = ['PII', 'PHI', 'PCI', 'PHI-PCI']
btlist = ['error', 'theft', 'hack']
paslist = [1, 50, 100]
rblist = ['true', 'false']
nclist = ['low', 'medium', 'high']
pplist = ['small', 'medium', 'large']
sqlist = ['below', 'average', 'above']
calist = ['true', 'false']

# %% [markdown]
# Start by trying every combination of discrete values with three options for each of those which accept many integers. The following creates 23,328 lines containing each possible combination of variables.

# %%
i=0
for ro in rolist:
    for nr in nrlist:
        for rt in rtlist:
            for bt in btlist:
                for pas in paslist:
                    for rb in rblist:
                        for nc in nclist:
                            for pp in pplist:
                                for sq in sqlist:
                                    for ca in calist:
                                        #print(str(i)+ro+str(nr)+rt+bt+str(pas)+rb+nc+pp+sq+ca)
                                        i+=1
print(i)
# Out:
# 23328

# %% [markdown]
# It doesn't make any sense to try to work with 23,328 combinations. I wouldn't know what to do with the results once I got them. I will try rebuilding the calculator systematically and piece by piece.
#
# I'll start with the first three variables, which they say on the calculator itself should give you a rough estimate of the overall cost before you answer the rest of the information.
#
# Let's try every combination of rolist, rtlist, and 3 values for nrlist and see what we get returned.
#
# We will take out all of the extraneous information and condense the results into a dataframe which will be easy to work with.

# %%
for ro in rolist:
    for nr in nrlist:
        for rt in rtlist:
            url = 'https://www.at-bay.com/bp/api/gui/v1/financial_exposure/calculate?record_owner='+ro+'&num_records='+str(nr)+'&record_type='+rt
            http = urllib3.PoolManager()
            response = http.request('GET', url)
            soup = BeautifulSoup(response.data, "lxml")
            f = open('test.csv', "a")
            soupstr = str(soup)
            pfixsoupstr = soupstr.replace('<html><body><p>{"result": {','').replace(' "call_center": ','').replace('"breach_coach": ','').replace(' "class_action_fines_and_defense": ','').replace(' "credit_monitoring": ','').replace(' "crisis_management": ','').replace(' "forensics": ','').replace(' "notification": ','').replace(' "pci_fines": ','').replace(' "regulatory_fines_and_defense": ','').replace('}, "total": ',',').replace(' "cost_per_record": ', '').replace('}','').replace('\n','').replace('</p></body></html>','')
            f.write(ro+','+str(nr)+','+rt+','+pfixsoupstr+"\n")
            f.close()
# Out:
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# Recall that the response has the fields `"result": {"breach_coach": 25000, "call_center": 66000, "class_action_fines_and_defense": 5400000, "credit_monitoring": 120000, "crisis_management": 100000, "forensics": 90000, "notification": 2800, "pci_fines": 2800000, "regulatory_fines_and_defense": 6600000}, "total": 15203800, "cost_per_record": 165.2586956521739`, which I will label in the dataframe as `bc, cc, cafd, crem, crim,for,not,pci,reg,total,cpr`

# %%
import pandas as pd

df = pd.read_csv('test.csv',names=['ro','nr','rt','bc', 'cc', 'cafd', 'crem', 'crim','for','not','pcif','reg','total','cpr'])

df
# Out:
#                        ro         nr       rt      bc        cc      cafd  \
# 0           employee_only          1      PII   25000      1300         0
# 1           employee_only          1      PHI   25000      1300         0
# 2           employee_only          1      PCI   25000      1300         0
# 3           employee_only          1  PHI-PCI   25000      1300         0
# 4           employee_only      10000      PII   50000      6100    650000
# 5           employee_only      10000      PHI   50000      6100    880000
# 6           employee_only      10000      PCI   50000      6100    650000
# 7           employee_only      10000  PHI-PCI   50000      6100    880000
# 8           employee_only  100000000      PII  750000  88000000  18000000
# 9           employee_only  100000000      PHI  750000  88000000  18000000
# 10          employee_only  100000000      PCI  750000  88000000  13000000
# 11          employee_only  100000000  PHI-PCI  750000  88000000  18000000
# 12  customer_and_employee          1      PII   25000      1300         0
# 13  customer_and_employee          1      PHI   25000      1300         0
# 14  customer_and_employee          1      PCI   25000      1300         0
# 15  customer_and_employee          1  PHI-PCI   25000      1300         0
# 16  customer_and_employee      10000      PII   50000      6100    650000
# 17  customer_and_employee      10000      PHI   50000      6100    880000
# 18  customer_and_employee      10000      PCI   50000      6100    650000
# 19  customer_and_employee      10000  PHI-PCI   50000      6100    880000
# 20  customer_and_employee  100000000      PII  750000  88000000  18000000
# 21  customer_and_employee  100000000      PHI  750000  88000000  18000000
# 22  customer_and_employee  100000000      PCI  750000  88000000  13000000
# 23  customer_and_employee  100000000  PHI-PCI  750000  88000000  18000000
# 24          employee_only          1      PII   25000      1300         0
# 25          employee_only          1      PHI   25000      1300         0
# 26          employee_only          1      PCI   25000      1300         0
# 27          employee_only          1  PHI-PCI   25000      1300         0
# 28          employee_only      10000      PII   50000      6100    650000
# 29          employee_only      10000      PHI   50000      6100    880000
# 30          employee_only      10000      PCI   50000      6100    650000
# 31          employee_only      10000  PHI-PCI   50000      6100    880000
# 32          employee_only  100000000      PII  750000  88000000  18000000
# 33          employee_only  100000000      PHI  750000  88000000  18000000
# 34          employee_only  100000000      PCI  750000  88000000  13000000
# 35          employee_only  100000000  PHI-PCI  750000  88000000  18000000
# 36  customer_and_employee          1      PII   25000      1300         0
# 37  customer_and_employee          1      PHI   25000      1300         0
# 38  customer_and_employee          1      PCI   25000      1300         0
# 39  customer_and_employee          1  PHI-PCI   25000      1300         0
# 40  customer_and_employee      10000      PII   50000      6100    650000
# 41  customer_and_employee      10000      PHI   50000      6100    880000
# 42  customer_and_employee      10000      PCI   50000      6100    650000
# 43  customer_and_employee      10000  PHI-PCI   50000      6100    880000
# 44  customer_and_employee  100000000      PII  750000  88000000  18000000
# 45  customer_and_employee  100000000      PHI  750000  88000000  18000000
# 46  customer_and_employee  100000000      PCI  750000  88000000  13000000
# 47  customer_and_employee  100000000  PHI-PCI  750000  88000000  18000000
#
#          crem    crim      for       not       pcif       reg       total  \
# 0          10   30000    60000      2800          0    280000      399110
# 1          10   40000    60000      2800          0    530000      659110
# 2          10   20000   120000      2800      75000    280000      524110
# 3          10   40000   120000      2800      75000    530000      794110
# 4       74000   53000    60000     15000          0    280000     1188100
# 5       89000   70000    60000     15000          0    530000     1700100
# 6       59000   35000   120000     15000     380000    280000     1595100
# 7       89000   70000   120000     15000     380000    530000     2140100
# 8   490000000  300000   750000  56000000          0  20000000   673800000
# 9   490000000  400000   750000  56000000          0  41000000   694900000
# 10  490000000  200000  1500000  56000000  400000000  20000000  1069450000
# 11  490000000  400000  1500000  56000000  400000000  41000000  1095650000
# 12          0   30000    60000      2800          0    280000      399100
# 13          0   40000    60000      2800          0    530000      659100
# 14          0   20000   120000      2800      75000    280000      524100
# 15          0   40000   120000      2800      75000    530000      794100
# 16       8200   53000    60000     15000          0    280000     1122300
# 17      11000   70000    60000     15000          0    530000     1622100
# 18       5200   35000   120000     15000     380000    280000     1541300
# 19      11000   70000   120000     15000     380000    530000     2062100
# 20   98000000  300000   750000  56000000          0  20000000   281800000
# 21   98000000  400000   750000  56000000          0  41000000   302900000
# 22   98000000  200000  1500000  56000000  400000000  20000000   677450000
# 23   98000000  400000  1500000  56000000  400000000  41000000   703650000
# 24         10   30000    60000      2800          0    280000      399110
# 25         10   40000    60000      2800          0    530000      659110
# 26         10   20000   120000      2800      75000    280000      524110
# 27         10   40000   120000      2800      75000    530000      794110
# 28      74000   53000    60000     15000          0    280000     1188100
# 29      89000   70000    60000     15000          0    530000     1700100
# 30      59000   35000   120000     15000     380000    280000     1595100
# 31      89000   70000   120000     15000     380000    530000     2140100
# 32  490000000  300000   750000  56000000          0  20000000   673800000
# 33  490000000  400000   750000  56000000          0  41000000   694900000
# 34  490000000  200000  1500000  56000000  400000000  20000000  1069450000
# 35  490000000  400000  1500000  56000000  400000000  41000000  1095650000
# 36          0   30000    60000      2800          0    280000      399100
# 37          0   40000    60000      2800          0    530000      659100
# 38          0   20000   120000      2800      75000    280000      524100
# 39          0   40000   120000      2800      75000    530000      794100
# 40       8200   53000    60000     15000          0    280000     1122300
# 41      11000   70000    60000     15000          0    530000     1622100
# 42       5200   35000   120000     15000     380000    280000     1541300
# 43      11000   70000   120000     15000     380000    530000     2062100
# 44   98000000  300000   750000  56000000          0  20000000   281800000
# 45   98000000  400000   750000  56000000          0  41000000   302900000
# 46   98000000  200000  1500000  56000000  400000000  20000000   677450000
# 47   98000000  400000  1500000  56000000  400000000  41000000   703650000
#
#             cpr
# 0   399110.0000
# 1   659110.0000
# 2   524110.0000
# 3   794110.0000
# 4      118.8100
# 5      170.0100
# 6      159.5100
# 7      214.0100
# 8        6.7380
# 9        6.9490
# 10      10.6945
# 11      10.9565
# 12  399100.0000
# 13  659100.0000
# 14  524100.0000
# 15  794100.0000
# 16     112.2300
# 17     162.2100
# 18     154.1300
# 19     206.2100
# 20       2.8180
# 21       3.0290
# 22       6.7745
# 23       7.0365
# 24  399110.0000
# 25  659110.0000
# 26  524110.0000
# 27  794110.0000
# 28     118.8100
# 29     170.0100
# 30     159.5100
# 31     214.0100
# 32       6.7380
# 33       6.9490
# 34      10.6945
# 35      10.9565
# 36  399100.0000
# 37  659100.0000
# 38  524100.0000
# 39  794100.0000
# 40     112.2300
# 41     162.2100
# 42     154.1300
# 43     206.2100
# 44       2.8180
# 45       3.0290
# 46       6.7745
# 47       7.0365

# %%
def ispci(df):
    if df['rt'] == 'PCI':
        return 'Yes'
    elif df['rt'] == 'PHI-PCI':
        return 'Yes'
    else:
        return 'No'

df['ispci'] = df.apply(ispci, axis=1)

# %%
def isphi(df):
    if df['rt'] == 'PHI':
        return 'Yes'
    elif df['rt'] == 'PHI-PCI':
        return 'Yes'
    else:
        return 'No'

df['isphi'] = df.apply(isphi, axis=1)

# %%
newdf = df.drop(columns=['rt'])
newdf
# Out:
#                        ro         nr      bc        cc      cafd       crem  \
# 0           employee_only          1   25000      1300         0         10
# 1           employee_only          1   25000      1300         0         10
# 2           employee_only          1   25000      1300         0         10
# 3           employee_only          1   25000      1300         0         10
# 4           employee_only      10000   50000      6100    650000      74000
# 5           employee_only      10000   50000      6100    880000      89000
# 6           employee_only      10000   50000      6100    650000      59000
# 7           employee_only      10000   50000      6100    880000      89000
# 8           employee_only  100000000  750000  88000000  18000000  490000000
# 9           employee_only  100000000  750000  88000000  18000000  490000000
# 10          employee_only  100000000  750000  88000000  13000000  490000000
# 11          employee_only  100000000  750000  88000000  18000000  490000000
# 12  customer_and_employee          1   25000      1300         0          0
# 13  customer_and_employee          1   25000      1300         0          0
# 14  customer_and_employee          1   25000      1300         0          0
# 15  customer_and_employee          1   25000      1300         0          0
# 16  customer_and_employee      10000   50000      6100    650000       8200
# 17  customer_and_employee      10000   50000      6100    880000      11000
# 18  customer_and_employee      10000   50000      6100    650000       5200
# 19  customer_and_employee      10000   50000      6100    880000      11000
# 20  customer_and_employee  100000000  750000  88000000  18000000   98000000
# 21  customer_and_employee  100000000  750000  88000000  18000000   98000000
# 22  customer_and_employee  100000000  750000  88000000  13000000   98000000
# 23  customer_and_employee  100000000  750000  88000000  18000000   98000000
# 24          employee_only          1   25000      1300         0         10
# 25          employee_only          1   25000      1300         0         10
# 26          employee_only          1   25000      1300         0         10
# 27          employee_only          1   25000      1300         0         10
# 28          employee_only      10000   50000      6100    650000      74000
# 29          employee_only      10000   50000      6100    880000      89000
# 30          employee_only      10000   50000      6100    650000      59000
# 31          employee_only      10000   50000      6100    880000      89000
# 32          employee_only  100000000  750000  88000000  18000000  490000000
# 33          employee_only  100000000  750000  88000000  18000000  490000000
# 34          employee_only  100000000  750000  88000000  13000000  490000000
# 35          employee_only  100000000  750000  88000000  18000000  490000000
# 36  customer_and_employee          1   25000      1300         0          0
# 37  customer_and_employee          1   25000      1300         0          0
# 38  customer_and_employee          1   25000      1300         0          0
# 39  customer_and_employee          1   25000      1300         0          0
# 40  customer_and_employee      10000   50000      6100    650000       8200
# 41  customer_and_employee      10000   50000      6100    880000      11000
# 42  customer_and_employee      10000   50000      6100    650000       5200
# 43  customer_and_employee      10000   50000      6100    880000      11000
# 44  customer_and_employee  100000000  750000  88000000  18000000   98000000
# 45  customer_and_employee  100000000  750000  88000000  18000000   98000000
# 46  customer_and_employee  100000000  750000  88000000  13000000   98000000
# 47  customer_and_employee  100000000  750000  88000000  18000000   98000000
#
#       crim      for       not       pcif       reg       total          cpr  \
# 0    30000    60000      2800          0    280000      399110  399110.0000
# 1    40000    60000      2800          0    530000      659110  659110.0000
# 2    20000   120000      2800      75000    280000      524110  524110.0000
# 3    40000   120000      2800      75000    530000      794110  794110.0000
# 4    53000    60000     15000          0    280000     1188100     118.8100
# 5    70000    60000     15000          0    530000     1700100     170.0100
# 6    35000   120000     15000     380000    280000     1595100     159.5100
# 7    70000   120000     15000     380000    530000     2140100     214.0100
# 8   300000   750000  56000000          0  20000000   673800000       6.7380
# 9   400000   750000  56000000          0  41000000   694900000       6.9490
# 10  200000  1500000  56000000  400000000  20000000  1069450000      10.6945
# 11  400000  1500000  56000000  400000000  41000000  1095650000      10.9565
# 12   30000    60000      2800          0    280000      399100  399100.0000
# 13   40000    60000      2800          0    530000      659100  659100.0000
# 14   20000   120000      2800      75000    280000      524100  524100.0000
# 15   40000   120000      2800      75000    530000      794100  794100.0000
# 16   53000    60000     15000          0    280000     1122300     112.2300
# 17   70000    60000     15000          0    530000     1622100     162.2100
# 18   35000   120000     15000     380000    280000     1541300     154.1300
# 19   70000   120000     15000     380000    530000     2062100     206.2100
# 20  300000   750000  56000000          0  20000000   281800000       2.8180
# 21  400000   750000  56000000          0  41000000   302900000       3.0290
# 22  200000  1500000  56000000  400000000  20000000   677450000       6.7745
# 23  400000  1500000  56000000  400000000  41000000   703650000       7.0365
# 24   30000    60000      2800          0    280000      399110  399110.0000
# 25   40000    60000      2800          0    530000      659110  659110.0000
# 26   20000   120000      2800      75000    280000      524110  524110.0000
# 27   40000   120000      2800      75000    530000      794110  794110.0000
# 28   53000    60000     15000          0    280000     1188100     118.8100
# 29   70000    60000     15000          0    530000     1700100     170.0100
# 30   35000   120000     15000     380000    280000     1595100     159.5100
# 31   70000   120000     15000     380000    530000     2140100     214.0100
# 32  300000   750000  56000000          0  20000000   673800000       6.7380
# 33  400000   750000  56000000          0  41000000   694900000       6.9490
# 34  200000  1500000  56000000  400000000  20000000  1069450000      10.6945
# 35  400000  1500000  56000000  400000000  41000000  1095650000      10.9565
# 36   30000    60000      2800          0    280000      399100  399100.0000
# 37   40000    60000      2800          0    530000      659100  659100.0000
# 38   20000   120000      2800      75000    280000      524100  524100.0000
# 39   40000   120000      2800      75000    530000      794100  794100.0000
# 40   53000    60000     15000          0    280000     1122300     112.2300
# 41   70000    60000     15000          0    530000     1622100     162.2100
# 42   35000   120000     15000     380000    280000     1541300     154.1300
# 43   70000   120000     15000     380000    530000     2062100     206.2100
# 44  300000   750000  56000000          0  20000000   281800000       2.8180
# 45  400000   750000  56000000          0  41000000   302900000       3.0290
# 46  200000  1500000  56000000  400000000  20000000   677450000       6.7745
# 47  400000  1500000  56000000  400000000  41000000   703650000       7.0365
#
#    ispci isphi
# 0     No    No
# 1     No   Yes
# 2    Yes    No
# 3    Yes   Yes
# 4     No    No
# 5     No   Yes
# 6    Yes    No
# 7    Yes   Yes
# 8     No    No
# 9     No   Yes
# 10   Yes    No
# 11   Yes   Yes
# 12    No    No
# 13    No   Yes
# 14   Yes    No
# 15   Yes   Yes
# 16    No    No
# 17    No   Yes
# 18   Yes    No
# 19   Yes   Yes
# 20    No    No
# 21    No   Yes
# 22   Yes    No
# 23   Yes   Yes
# 24    No    No
# 25    No   Yes
# 26   Yes    No
# 27   Yes   Yes
# 28    No    No
# 29    No   Yes
# 30   Yes    No
# 31   Yes   Yes
# 32    No    No
# 33    No   Yes
# 34   Yes    No
# 35   Yes   Yes
# 36    No    No
# 37    No   Yes
# 38   Yes    No
# 39   Yes   Yes
# 40    No    No
# 41    No   Yes
# 42   Yes    No
# 43   Yes   Yes
# 44    No    No
# 45    No   Yes
# 46   Yes    No
# 47   Yes   Yes

# %% [markdown]
# going back in time to before changing that variable.. since im not exactly sure what the point of that was anyway.|

# %%
pr_df = df[['bc','cc','cafd', 'crem', 'crim','for','not','pcif','reg']].div(df.nr, axis=0)

lab_df = df[['ro','rt','nr','cpr']]

pr_df = pr_df.join(lab_df)
pr_df
# Out:
#             bc       cc   cafd   crem       crim          for      not  \
# 0   25000.0000  1300.00   0.00  10.00  30000.000   60000.0000  2800.00
# 1   25000.0000  1300.00   0.00  10.00  40000.000   60000.0000  2800.00
# 2   25000.0000  1300.00   0.00  10.00  20000.000  120000.0000  2800.00
# 3   25000.0000  1300.00   0.00  10.00  40000.000  120000.0000  2800.00
# 4       5.0000     0.61  65.00   7.40      5.300       6.0000     1.50
# 5       5.0000     0.61  88.00   8.90      7.000       6.0000     1.50
# 6       5.0000     0.61  65.00   5.90      3.500      12.0000     1.50
# 7       5.0000     0.61  88.00   8.90      7.000      12.0000     1.50
# 8       0.0075     0.88   0.18   4.90      0.003       0.0075     0.56
# 9       0.0075     0.88   0.18   4.90      0.004       0.0075     0.56
# 10      0.0075     0.88   0.13   4.90      0.002       0.0150     0.56
# 11      0.0075     0.88   0.18   4.90      0.004       0.0150     0.56
# 12  25000.0000  1300.00   0.00   0.00  30000.000   60000.0000  2800.00
# 13  25000.0000  1300.00   0.00   0.00  40000.000   60000.0000  2800.00
# 14  25000.0000  1300.00   0.00   0.00  20000.000  120000.0000  2800.00
# 15  25000.0000  1300.00   0.00   0.00  40000.000  120000.0000  2800.00
# 16      5.0000     0.61  65.00   0.82      5.300       6.0000     1.50
# 17      5.0000     0.61  88.00   1.10      7.000       6.0000     1.50
# 18      5.0000     0.61  65.00   0.52      3.500      12.0000     1.50
# 19      5.0000     0.61  88.00   1.10      7.000      12.0000     1.50
# 20      0.0075     0.88   0.18   0.98      0.003       0.0075     0.56
# 21      0.0075     0.88   0.18   0.98      0.004       0.0075     0.56
# 22      0.0075     0.88   0.13   0.98      0.002       0.0150     0.56
# 23      0.0075     0.88   0.18   0.98      0.004       0.0150     0.56
# 24  25000.0000  1300.00   0.00  10.00  30000.000   60000.0000  2800.00
# 25  25000.0000  1300.00   0.00  10.00  40000.000   60000.0000  2800.00
# 26  25000.0000  1300.00   0.00  10.00  20000.000  120000.0000  2800.00
# 27  25000.0000  1300.00   0.00  10.00  40000.000  120000.0000  2800.00
# 28      5.0000     0.61  65.00   7.40      5.300       6.0000     1.50
# 29      5.0000     0.61  88.00   8.90      7.000       6.0000     1.50
# 30      5.0000     0.61  65.00   5.90      3.500      12.0000     1.50
# 31      5.0000     0.61  88.00   8.90      7.000      12.0000     1.50
# 32      0.0075     0.88   0.18   4.90      0.003       0.0075     0.56
# 33      0.0075     0.88   0.18   4.90      0.004       0.0075     0.56
# 34      0.0075     0.88   0.13   4.90      0.002       0.0150     0.56
# 35      0.0075     0.88   0.18   4.90      0.004       0.0150     0.56
# 36  25000.0000  1300.00   0.00   0.00  30000.000   60000.0000  2800.00
# 37  25000.0000  1300.00   0.00   0.00  40000.000   60000.0000  2800.00
# 38  25000.0000  1300.00   0.00   0.00  20000.000  120000.0000  2800.00
# 39  25000.0000  1300.00   0.00   0.00  40000.000  120000.0000  2800.00
# 40      5.0000     0.61  65.00   0.82      5.300       6.0000     1.50
# 41      5.0000     0.61  88.00   1.10      7.000       6.0000     1.50
# 42      5.0000     0.61  65.00   0.52      3.500      12.0000     1.50
# 43      5.0000     0.61  88.00   1.10      7.000      12.0000     1.50
# 44      0.0075     0.88   0.18   0.98      0.003       0.0075     0.56
# 45      0.0075     0.88   0.18   0.98      0.004       0.0075     0.56
# 46      0.0075     0.88   0.13   0.98      0.002       0.0150     0.56
# 47      0.0075     0.88   0.18   0.98      0.004       0.0150     0.56
#
#        pcif        reg                     ro       rt         nr          cpr
# 0       0.0  280000.00          employee_only      PII          1  399110.0000
# 1       0.0  530000.00          employee_only      PHI          1  659110.0000
# 2   75000.0  280000.00          employee_only      PCI          1  524110.0000
# 3   75000.0  530000.00          employee_only  PHI-PCI          1  794110.0000
# 4       0.0      28.00          employee_only      PII      10000     118.8100
# 5       0.0      53.00          employee_only      PHI      10000     170.0100
# 6      38.0      28.00          employee_only      PCI      10000     159.5100
# 7      38.0      53.00          employee_only  PHI-PCI      10000     214.0100
# 8       0.0       0.20          employee_only      PII  100000000       6.7380
# 9       0.0       0.41          employee_only      PHI  100000000       6.9490
# 10      4.0       0.20          employee_only      PCI  100000000      10.6945
# 11      4.0       0.41          employee_only  PHI-PCI  100000000      10.9565
# 12      0.0  280000.00  customer_and_employee      PII          1  399100.0000
# 13      0.0  530000.00  customer_and_employee      PHI          1  659100.0000
# 14  75000.0  280000.00  customer_and_employee      PCI          1  524100.0000
# 15  75000.0  530000.00  customer_and_employee  PHI-PCI          1  794100.0000
# 16      0.0      28.00  customer_and_employee      PII      10000     112.2300
# 17      0.0      53.00  customer_and_employee      PHI      10000     162.2100
# 18     38.0      28.00  customer_and_employee      PCI      10000     154.1300
# 19     38.0      53.00  customer_and_employee  PHI-PCI      10000     206.2100
# 20      0.0       0.20  customer_and_employee      PII  100000000       2.8180
# 21      0.0       0.41  customer_and_employee      PHI  100000000       3.0290
# 22      4.0       0.20  customer_and_employee      PCI  100000000       6.7745
# 23      4.0       0.41  customer_and_employee  PHI-PCI  100000000       7.0365
# 24      0.0  280000.00          employee_only      PII          1  399110.0000
# 25      0.0  530000.00          employee_only      PHI          1  659110.0000
# 26  75000.0  280000.00          employee_only      PCI          1  524110.0000
# 27  75000.0  530000.00          employee_only  PHI-PCI          1  794110.0000
# 28      0.0      28.00          employee_only      PII      10000     118.8100
# 29      0.0      53.00          employee_only      PHI      10000     170.0100
# 30     38.0      28.00          employee_only      PCI      10000     159.5100
# 31     38.0      53.00          employee_only  PHI-PCI      10000     214.0100
# 32      0.0       0.20          employee_only      PII  100000000       6.7380
# 33      0.0       0.41          employee_only      PHI  100000000       6.9490
# 34      4.0       0.20          employee_only      PCI  100000000      10.6945
# 35      4.0       0.41          employee_only  PHI-PCI  100000000      10.9565
# 36      0.0  280000.00  customer_and_employee      PII          1  399100.0000
# 37      0.0  530000.00  customer_and_employee      PHI          1  659100.0000
# 38  75000.0  280000.00  customer_and_employee      PCI          1  524100.0000
# 39  75000.0  530000.00  customer_and_employee  PHI-PCI          1  794100.0000
# 40      0.0      28.00  customer_and_employee      PII      10000     112.2300
# 41      0.0      53.00  customer_and_employee      PHI      10000     162.2100
# 42     38.0      28.00  customer_and_employee      PCI      10000     154.1300
# 43     38.0      53.00  customer_and_employee  PHI-PCI      10000     206.2100
# 44      0.0       0.20  customer_and_employee      PII  100000000       2.8180
# 45      0.0       0.41  customer_and_employee      PHI  100000000       3.0290
# 46      4.0       0.20  customer_and_employee      PCI  100000000       6.7745
# 47      4.0       0.41  customer_and_employee  PHI-PCI  100000000       7.0365

# %%
pr_ie = pr_df.loc[(pr_df["ro"] == 'employee_only') & (pr_df["rt"] == 'PII')]
pr_iu = pr_df.loc[(pr_df["ro"] == 'customer_and_employee') & (pr_df["rt"] == 'PII')]
pr_he = pr_df.loc[(pr_df["ro"] == 'employee_only') & (pr_df["rt"] == 'PHI')]
pr_hu = pr_df.loc[(pr_df["ro"] == 'customer_and_employee') & (pr_df["rt"] == 'PHI')]
pr_ce = pr_df.loc[(pr_df["ro"] == 'employee_only') & (pr_df["rt"] == 'PCI')]
pr_cu = pr_df.loc[(pr_df["ro"] == 'customer_and_employee') & (pr_df["rt"] == 'PCI')]
pr_hce = pr_df.loc[(pr_df["ro"] == 'employee_only') & (pr_df["rt"] == 'PHI-PCI')]
pr_hcu = pr_df.loc[(pr_df["ro"] == 'customer_and_employee') & (pr_df["rt"] == 'PHI-PCI')]

# %%
lvls =['ie', 'iu','he', 'hu','ce', 'cu','hce', 'hcu']
blvls = ['bc', 'cc','cafd', 'crem','crim', 'for','not', 'pcif', 'reg', 'cpr']

def do_thing(l,b):
    a = "pr_"+l+"_"+b+" = {'1': pr_"+l+"['"+b+"'].iloc[0],'10000': pr_"+l+"['"+b+"'].iloc[1],'1000000000': pr_"+l+"['"+b+"'].iloc[2]}"
    a
    print(a)

for l in lvls:
    for b in blvls:
        do_thing(l,b)
# how to get this so it actually runs rather than just printing out all the lines?????
# Out:
# pr_ie_bc = {'1': pr_ie['bc'].iloc[0],'10000': pr_ie['bc'].iloc[1],'1000000000': pr_ie['bc'].iloc[2]}
# pr_ie_cc = {'1': pr_ie['cc'].iloc[0],'10000': pr_ie['cc'].iloc[1],'1000000000': pr_ie['cc'].iloc[2]}
# pr_ie_cafd = {'1': pr_ie['cafd'].iloc[0],'10000': pr_ie['cafd'].iloc[1],'1000000000': pr_ie['cafd'].iloc[2]}
# pr_ie_crem = {'1': pr_ie['crem'].iloc[0],'10000': pr_ie['crem'].iloc[1],'1000000000': pr_ie['crem'].iloc[2]}
# pr_ie_crim = {'1': pr_ie['crim'].iloc[0],'10000': pr_ie['crim'].iloc[1],'1000000000': pr_ie['crim'].iloc[2]}
# pr_ie_for = {'1': pr_ie['for'].iloc[0],'10000': pr_ie['for'].iloc[1],'1000000000': pr_ie['for'].iloc[2]}
# pr_ie_not = {'1': pr_ie['not'].iloc[0],'10000': pr_ie['not'].iloc[1],'1000000000': pr_ie['not'].iloc[2]}
# pr_ie_pcif = {'1': pr_ie['pcif'].iloc[0],'10000': pr_ie['pcif'].iloc[1],'1000000000': pr_ie['pcif'].iloc[2]}
# pr_ie_reg = {'1': pr_ie['reg'].iloc[0],'10000': pr_ie['reg'].iloc[1],'1000000000': pr_ie['reg'].iloc[2]}
# pr_ie_cpr = {'1': pr_ie['cpr'].iloc[0],'10000': pr_ie['cpr'].iloc[1],'1000000000': pr_ie['cpr'].iloc[2]}
# pr_iu_bc = {'1': pr_iu['bc'].iloc[0],'10000': pr_iu['bc'].iloc[1],'1000000000': pr_iu['bc'].iloc[2]}
# pr_iu_cc = {'1': pr_iu['cc'].iloc[0],'10000': pr_iu['cc'].iloc[1],'1000000000': pr_iu['cc'].iloc[2]}
# pr_iu_cafd = {'1': pr_iu['cafd'].iloc[0],'10000': pr_iu['cafd'].iloc[1],'1000000000': pr_iu['cafd'].iloc[2]}
# pr_iu_crem = {'1': pr_iu['crem'].iloc[0],'10000': pr_iu['crem'].iloc[1],'1000000000': pr_iu['crem'].iloc[2]}
# pr_iu_crim = {'1': pr_iu['crim'].iloc[0],'10000': pr_iu['crim'].iloc[1],'1000000000': pr_iu['crim'].iloc[2]}
# pr_iu_for = {'1': pr_iu['for'].iloc[0],'10000': pr_iu['for'].iloc[1],'1000000000': pr_iu['for'].iloc[2]}
# pr_iu_not = {'1': pr_iu['not'].iloc[0],'10000': pr_iu['not'].iloc[1],'1000000000': pr_iu['not'].iloc[2]}
# pr_iu_pcif = {'1': pr_iu['pcif'].iloc[0],'10000': pr_iu['pcif'].iloc[1],'1000000000': pr_iu['pcif'].iloc[2]}
# pr_iu_reg = {'1': pr_iu['reg'].iloc[0],'10000': pr_iu['reg'].iloc[1],'1000000000': pr_iu['reg'].iloc[2]}
# pr_iu_cpr = {'1': pr_iu['cpr'].iloc[0],'10000': pr_iu['cpr'].iloc[1],'1000000000': pr_iu['cpr'].iloc[2]}
# pr_he_bc = {'1': pr_he['bc'].iloc[0],'10000': pr_he['bc'].iloc[1],'1000000000': pr_he['bc'].iloc[2]}
# pr_he_cc = {'1': pr_he['cc'].iloc[0],'10000': pr_he['cc'].iloc[1],'1000000000': pr_he['cc'].iloc[2]}
# pr_he_cafd = {'1': pr_he['cafd'].iloc[0],'10000': pr_he['cafd'].iloc[1],'1000000000': pr_he['cafd'].iloc[2]}
# pr_he_crem = {'1': pr_he['crem'].iloc[0],'10000': pr_he['crem'].iloc[1],'1000000000': pr_he['crem'].iloc[2]}
# pr_he_crim = {'1': pr_he['crim'].iloc[0],'10000': pr_he['crim'].iloc[1],'1000000000': pr_he['crim'].iloc[2]}
# pr_he_for = {'1': pr_he['for'].iloc[0],'10000': pr_he['for'].iloc[1],'1000000000': pr_he['for'].iloc[2]}
# pr_he_not = {'1': pr_he['not'].iloc[0],'10000': pr_he['not'].iloc[1],'1000000000': pr_he['not'].iloc[2]}
# pr_he_pcif = {'1': pr_he['pcif'].iloc[0],'10000': pr_he['pcif'].iloc[1],'1000000000': pr_he['pcif'].iloc[2]}
# pr_he_reg = {'1': pr_he['reg'].iloc[0],'10000': pr_he['reg'].iloc[1],'1000000000': pr_he['reg'].iloc[2]}
# pr_he_cpr = {'1': pr_he['cpr'].iloc[0],'10000': pr_he['cpr'].iloc[1],'1000000000': pr_he['cpr'].iloc[2]}
# pr_hu_bc = {'1': pr_hu['bc'].iloc[0],'10000': pr_hu['bc'].iloc[1],'1000000000': pr_hu['bc'].iloc[2]}
# pr_hu_cc = {'1': pr_hu['cc'].iloc[0],'10000': pr_hu['cc'].iloc[1],'1000000000': pr_hu['cc'].iloc[2]}
# pr_hu_cafd = {'1': pr_hu['cafd'].iloc[0],'10000': pr_hu['cafd'].iloc[1],'1000000000': pr_hu['cafd'].iloc[2]}
# pr_hu_crem = {'1': pr_hu['crem'].iloc[0],'10000': pr_hu['crem'].iloc[1],'1000000000': pr_hu['crem'].iloc[2]}
# pr_hu_crim = {'1': pr_hu['crim'].iloc[0],'10000': pr_hu['crim'].iloc[1],'1000000000': pr_hu['crim'].iloc[2]}
# pr_hu_for = {'1': pr_hu['for'].iloc[0],'10000': pr_hu['for'].iloc[1],'1000000000': pr_hu['for'].iloc[2]}
# pr_hu_not = {'1': pr_hu['not'].iloc[0],'10000': pr_hu['not'].iloc[1],'1000000000': pr_hu['not'].iloc[2]}
# pr_hu_pcif = {'1': pr_hu['pcif'].iloc[0],'10000': pr_hu['pcif'].iloc[1],'1000000000': pr_hu['pcif'].iloc[2]}
# pr_hu_reg = {'1': pr_hu['reg'].iloc[0],'10000': pr_hu['reg'].iloc[1],'1000000000': pr_hu['reg'].iloc[2]}
# pr_hu_cpr = {'1': pr_hu['cpr'].iloc[0],'10000': pr_hu['cpr'].iloc[1],'1000000000': pr_hu['cpr'].iloc[2]}
# pr_ce_bc = {'1': pr_ce['bc'].iloc[0],'10000': pr_ce['bc'].iloc[1],'1000000000': pr_ce['bc'].iloc[2]}
# pr_ce_cc = {'1': pr_ce['cc'].iloc[0],'10000': pr_ce['cc'].iloc[1],'1000000000': pr_ce['cc'].iloc[2]}
# pr_ce_cafd = {'1': pr_ce['cafd'].iloc[0],'10000': pr_ce['cafd'].iloc[1],'1000000000': pr_ce['cafd'].iloc[2]}
# pr_ce_crem = {'1': pr_ce['crem'].iloc[0],'10000': pr_ce['crem'].iloc[1],'1000000000': pr_ce['crem'].iloc[2]}
# pr_ce_crim = {'1': pr_ce['crim'].iloc[0],'10000': pr_ce['crim'].iloc[1],'1000000000': pr_ce['crim'].iloc[2]}
# pr_ce_for = {'1': pr_ce['for'].iloc[0],'10000': pr_ce['for'].iloc[1],'1000000000': pr_ce['for'].iloc[2]}
# pr_ce_not = {'1': pr_ce['not'].iloc[0],'10000': pr_ce['not'].iloc[1],'1000000000': pr_ce['not'].iloc[2]}
# pr_ce_pcif = {'1': pr_ce['pcif'].iloc[0],'10000': pr_ce['pcif'].iloc[1],'1000000000': pr_ce['pcif'].iloc[2]}
# pr_ce_reg = {'1': pr_ce['reg'].iloc[0],'10000': pr_ce['reg'].iloc[1],'1000000000': pr_ce['reg'].iloc[2]}
# pr_ce_cpr = {'1': pr_ce['cpr'].iloc[0],'10000': pr_ce['cpr'].iloc[1],'1000000000': pr_ce['cpr'].iloc[2]}
# pr_cu_bc = {'1': pr_cu['bc'].iloc[0],'10000': pr_cu['bc'].iloc[1],'1000000000': pr_cu['bc'].iloc[2]}
# pr_cu_cc = {'1': pr_cu['cc'].iloc[0],'10000': pr_cu['cc'].iloc[1],'1000000000': pr_cu['cc'].iloc[2]}
# pr_cu_cafd = {'1': pr_cu['cafd'].iloc[0],'10000': pr_cu['cafd'].iloc[1],'1000000000': pr_cu['cafd'].iloc[2]}
# pr_cu_crem = {'1': pr_cu['crem'].iloc[0],'10000': pr_cu['crem'].iloc[1],'1000000000': pr_cu['crem'].iloc[2]}
# pr_cu_crim = {'1': pr_cu['crim'].iloc[0],'10000': pr_cu['crim'].iloc[1],'1000000000': pr_cu['crim'].iloc[2]}
# pr_cu_for = {'1': pr_cu['for'].iloc[0],'10000': pr_cu['for'].iloc[1],'1000000000': pr_cu['for'].iloc[2]}
# pr_cu_not = {'1': pr_cu['not'].iloc[0],'10000': pr_cu['not'].iloc[1],'1000000000': pr_cu['not'].iloc[2]}
# pr_cu_pcif = {'1': pr_cu['pcif'].iloc[0],'10000': pr_cu['pcif'].iloc[1],'1000000000': pr_cu['pcif'].iloc[2]}
# pr_cu_reg = {'1': pr_cu['reg'].iloc[0],'10000': pr_cu['reg'].iloc[1],'1000000000': pr_cu['reg'].iloc[2]}
# pr_cu_cpr = {'1': pr_cu['cpr'].iloc[0],'10000': pr_cu['cpr'].iloc[1],'1000000000': pr_cu['cpr'].iloc[2]}
# pr_hce_bc = {'1': pr_hce['bc'].iloc[0],'10000': pr_hce['bc'].iloc[1],'1000000000': pr_hce['bc'].iloc[2]}
# pr_hce_cc = {'1': pr_hce['cc'].iloc[0],'10000': pr_hce['cc'].iloc[1],'1000000000': pr_hce['cc'].iloc[2]}
# pr_hce_cafd = {'1': pr_hce['cafd'].iloc[0],'10000': pr_hce['cafd'].iloc[1],'1000000000': pr_hce['cafd'].iloc[2]}
# pr_hce_crem = {'1': pr_hce['crem'].iloc[0],'10000': pr_hce['crem'].iloc[1],'1000000000': pr_hce['crem'].iloc[2]}
# pr_hce_crim = {'1': pr_hce['crim'].iloc[0],'10000': pr_hce['crim'].iloc[1],'1000000000': pr_hce['crim'].iloc[2]}
# pr_hce_for = {'1': pr_hce['for'].iloc[0],'10000': pr_hce['for'].iloc[1],'1000000000': pr_hce['for'].iloc[2]}
# pr_hce_not = {'1': pr_hce['not'].iloc[0],'10000': pr_hce['not'].iloc[1],'1000000000': pr_hce['not'].iloc[2]}
# pr_hce_pcif = {'1': pr_hce['pcif'].iloc[0],'10000': pr_hce['pcif'].iloc[1],'1000000000': pr_hce['pcif'].iloc[2]}
# pr_hce_reg = {'1': pr_hce['reg'].iloc[0],'10000': pr_hce['reg'].iloc[1],'1000000000': pr_hce['reg'].iloc[2]}
# pr_hce_cpr = {'1': pr_hce['cpr'].iloc[0],'10000': pr_hce['cpr'].iloc[1],'1000000000': pr_hce['cpr'].iloc[2]}
# pr_hcu_bc = {'1': pr_hcu['bc'].iloc[0],'10000': pr_hcu['bc'].iloc[1],'1000000000': pr_hcu['bc'].iloc[2]}
# pr_hcu_cc = {'1': pr_hcu['cc'].iloc[0],'10000': pr_hcu['cc'].iloc[1],'1000000000': pr_hcu['cc'].iloc[2]}
# pr_hcu_cafd = {'1': pr_hcu['cafd'].iloc[0],'10000': pr_hcu['cafd'].iloc[1],'1000000000': pr_hcu['cafd'].iloc[2]}
# pr_hcu_crem = {'1': pr_hcu['crem'].iloc[0],'10000': pr_hcu['crem'].iloc[1],'1000000000': pr_hcu['crem'].iloc[2]}
# pr_hcu_crim = {'1': pr_hcu['crim'].iloc[0],'10000': pr_hcu['crim'].iloc[1],'1000000000': pr_hcu['crim'].iloc[2]}
# pr_hcu_for = {'1': pr_hcu['for'].iloc[0],'10000': pr_hcu['for'].iloc[1],'1000000000': pr_hcu['for'].iloc[2]}
# pr_hcu_not = {'1': pr_hcu['not'].iloc[0],'10000': pr_hcu['not'].iloc[1],'1000000000': pr_hcu['not'].iloc[2]}
# pr_hcu_pcif = {'1': pr_hcu['pcif'].iloc[0],'10000': pr_hcu['pcif'].iloc[1],'1000000000': pr_hcu['pcif'].iloc[2]}
# pr_hcu_reg = {'1': pr_hcu['reg'].iloc[0],'10000': pr_hcu['reg'].iloc[1],'1000000000': pr_hcu['reg'].iloc[2]}
# pr_hcu_cpr = {'1': pr_hcu['cpr'].iloc[0],'10000': pr_hcu['cpr'].iloc[1],'1000000000': pr_hcu['cpr'].iloc[2]}

# %%
pr_hcu_crim
# Out:
# {'1': 40000.0, '10000': 7.0, '1000000000': 0.004}

# %%
def ready_for_graph(l,b):
    a = "pr_"+l+"_"+b+"_names = list(pr_"+l+"_"+b+".keys())"
    c = "pr_"+l+"_"+b+"_values = list(pr_"+l+"_"+b+".values())"
    print(a+'\n'+c)

for x in lvls:
    for y in blvls:
        ready_for_graph(x,y)
# Out:
# pr_ie_bc_names = list(pr_ie_bc.keys())
# pr_ie_bc_values = list(pr_ie_bc.values())
# pr_ie_cc_names = list(pr_ie_cc.keys())
# pr_ie_cc_values = list(pr_ie_cc.values())
# pr_ie_cafd_names = list(pr_ie_cafd.keys())
# pr_ie_cafd_values = list(pr_ie_cafd.values())
# pr_ie_crem_names = list(pr_ie_crem.keys())
# pr_ie_crem_values = list(pr_ie_crem.values())
# pr_ie_crim_names = list(pr_ie_crim.keys())
# pr_ie_crim_values = list(pr_ie_crim.values())
# pr_ie_for_names = list(pr_ie_for.keys())
# pr_ie_for_values = list(pr_ie_for.values())
# pr_ie_not_names = list(pr_ie_not.keys())
# pr_ie_not_values = list(pr_ie_not.values())
# pr_ie_pcif_names = list(pr_ie_pcif.keys())
# pr_ie_pcif_values = list(pr_ie_pcif.values())
# pr_ie_reg_names = list(pr_ie_reg.keys())
# pr_ie_reg_values = list(pr_ie_reg.values())
# pr_ie_cpr_names = list(pr_ie_cpr.keys())
# pr_ie_cpr_values = list(pr_ie_cpr.values())
# pr_iu_bc_names = list(pr_iu_bc.keys())
# pr_iu_bc_values = list(pr_iu_bc.values())
# pr_iu_cc_names = list(pr_iu_cc.keys())
# pr_iu_cc_values = list(pr_iu_cc.values())
# pr_iu_cafd_names = list(pr_iu_cafd.keys())
# pr_iu_cafd_values = list(pr_iu_cafd.values())
# pr_iu_crem_names = list(pr_iu_crem.keys())
# pr_iu_crem_values = list(pr_iu_crem.values())
# pr_iu_crim_names = list(pr_iu_crim.keys())
# pr_iu_crim_values = list(pr_iu_crim.values())
# pr_iu_for_names = list(pr_iu_for.keys())
# pr_iu_for_values = list(pr_iu_for.values())
# pr_iu_not_names = list(pr_iu_not.keys())
# pr_iu_not_values = list(pr_iu_not.values())
# pr_iu_pcif_names = list(pr_iu_pcif.keys())
# pr_iu_pcif_values = list(pr_iu_pcif.values())
# pr_iu_reg_names = list(pr_iu_reg.keys())
# pr_iu_reg_values = list(pr_iu_reg.values())
# pr_iu_cpr_names = list(pr_iu_cpr.keys())
# pr_iu_cpr_values = list(pr_iu_cpr.values())
# pr_he_bc_names = list(pr_he_bc.keys())
# pr_he_bc_values = list(pr_he_bc.values())
# pr_he_cc_names = list(pr_he_cc.keys())
# pr_he_cc_values = list(pr_he_cc.values())
# pr_he_cafd_names = list(pr_he_cafd.keys())
# pr_he_cafd_values = list(pr_he_cafd.values())
# pr_he_crem_names = list(pr_he_crem.keys())
# pr_he_crem_values = list(pr_he_crem.values())
# pr_he_crim_names = list(pr_he_crim.keys())
# pr_he_crim_values = list(pr_he_crim.values())
# pr_he_for_names = list(pr_he_for.keys())
# pr_he_for_values = list(pr_he_for.values())
# pr_he_not_names = list(pr_he_not.keys())
# pr_he_not_values = list(pr_he_not.values())
# pr_he_pcif_names = list(pr_he_pcif.keys())
# pr_he_pcif_values = list(pr_he_pcif.values())
# pr_he_reg_names = list(pr_he_reg.keys())
# pr_he_reg_values = list(pr_he_reg.values())
# pr_he_cpr_names = list(pr_he_cpr.keys())
# pr_he_cpr_values = list(pr_he_cpr.values())
# pr_hu_bc_names = list(pr_hu_bc.keys())
# pr_hu_bc_values = list(pr_hu_bc.values())
# pr_hu_cc_names = list(pr_hu_cc.keys())
# pr_hu_cc_values = list(pr_hu_cc.values())
# pr_hu_cafd_names = list(pr_hu_cafd.keys())
# pr_hu_cafd_values = list(pr_hu_cafd.values())
# pr_hu_crem_names = list(pr_hu_crem.keys())
# pr_hu_crem_values = list(pr_hu_crem.values())
# pr_hu_crim_names = list(pr_hu_crim.keys())
# pr_hu_crim_values = list(pr_hu_crim.values())
# pr_hu_for_names = list(pr_hu_for.keys())
# pr_hu_for_values = list(pr_hu_for.values())
# pr_hu_not_names = list(pr_hu_not.keys())
# pr_hu_not_values = list(pr_hu_not.values())
# pr_hu_pcif_names = list(pr_hu_pcif.keys())
# pr_hu_pcif_values = list(pr_hu_pcif.values())
# pr_hu_reg_names = list(pr_hu_reg.keys())
# pr_hu_reg_values = list(pr_hu_reg.values())
# pr_hu_cpr_names = list(pr_hu_cpr.keys())
# pr_hu_cpr_values = list(pr_hu_cpr.values())
# pr_ce_bc_names = list(pr_ce_bc.keys())
# pr_ce_bc_values = list(pr_ce_bc.values())
# pr_ce_cc_names = list(pr_ce_cc.keys())
# pr_ce_cc_values = list(pr_ce_cc.values())
# pr_ce_cafd_names = list(pr_ce_cafd.keys())
# pr_ce_cafd_values = list(pr_ce_cafd.values())
# pr_ce_crem_names = list(pr_ce_crem.keys())
# pr_ce_crem_values = list(pr_ce_crem.values())
# pr_ce_crim_names = list(pr_ce_crim.keys())
# pr_ce_crim_values = list(pr_ce_crim.values())
# pr_ce_for_names = list(pr_ce_for.keys())
# pr_ce_for_values = list(pr_ce_for.values())
# pr_ce_not_names = list(pr_ce_not.keys())
# pr_ce_not_values = list(pr_ce_not.values())
# pr_ce_pcif_names = list(pr_ce_pcif.keys())
# pr_ce_pcif_values = list(pr_ce_pcif.values())
# pr_ce_reg_names = list(pr_ce_reg.keys())
# pr_ce_reg_values = list(pr_ce_reg.values())
# pr_ce_cpr_names = list(pr_ce_cpr.keys())
# pr_ce_cpr_values = list(pr_ce_cpr.values())
# pr_cu_bc_names = list(pr_cu_bc.keys())
# pr_cu_bc_values = list(pr_cu_bc.values())
# pr_cu_cc_names = list(pr_cu_cc.keys())
# pr_cu_cc_values = list(pr_cu_cc.values())
# pr_cu_cafd_names = list(pr_cu_cafd.keys())
# pr_cu_cafd_values = list(pr_cu_cafd.values())
# pr_cu_crem_names = list(pr_cu_crem.keys())
# pr_cu_crem_values = list(pr_cu_crem.values())
# pr_cu_crim_names = list(pr_cu_crim.keys())
# pr_cu_crim_values = list(pr_cu_crim.values())
# pr_cu_for_names = list(pr_cu_for.keys())
# pr_cu_for_values = list(pr_cu_for.values())
# pr_cu_not_names = list(pr_cu_not.keys())
# pr_cu_not_values = list(pr_cu_not.values())
# pr_cu_pcif_names = list(pr_cu_pcif.keys())
# pr_cu_pcif_values = list(pr_cu_pcif.values())
# pr_cu_reg_names = list(pr_cu_reg.keys())
# pr_cu_reg_values = list(pr_cu_reg.values())
# pr_cu_cpr_names = list(pr_cu_cpr.keys())
# pr_cu_cpr_values = list(pr_cu_cpr.values())
# pr_hce_bc_names = list(pr_hce_bc.keys())
# pr_hce_bc_values = list(pr_hce_bc.values())
# pr_hce_cc_names = list(pr_hce_cc.keys())
# pr_hce_cc_values = list(pr_hce_cc.values())
# pr_hce_cafd_names = list(pr_hce_cafd.keys())
# pr_hce_cafd_values = list(pr_hce_cafd.values())
# pr_hce_crem_names = list(pr_hce_crem.keys())
# pr_hce_crem_values = list(pr_hce_crem.values())
# pr_hce_crim_names = list(pr_hce_crim.keys())
# pr_hce_crim_values = list(pr_hce_crim.values())
# pr_hce_for_names = list(pr_hce_for.keys())
# pr_hce_for_values = list(pr_hce_for.values())
# pr_hce_not_names = list(pr_hce_not.keys())
# pr_hce_not_values = list(pr_hce_not.values())
# pr_hce_pcif_names = list(pr_hce_pcif.keys())
# pr_hce_pcif_values = list(pr_hce_pcif.values())
# pr_hce_reg_names = list(pr_hce_reg.keys())
# pr_hce_reg_values = list(pr_hce_reg.values())
# pr_hce_cpr_names = list(pr_hce_cpr.keys())
# pr_hce_cpr_values = list(pr_hce_cpr.values())
# pr_hcu_bc_names = list(pr_hcu_bc.keys())
# pr_hcu_bc_values = list(pr_hcu_bc.values())
# pr_hcu_cc_names = list(pr_hcu_cc.keys())
# pr_hcu_cc_values = list(pr_hcu_cc.values())
# pr_hcu_cafd_names = list(pr_hcu_cafd.keys())
# pr_hcu_cafd_values = list(pr_hcu_cafd.values())
# pr_hcu_crem_names = list(pr_hcu_crem.keys())
# pr_hcu_crem_values = list(pr_hcu_crem.values())
# pr_hcu_crim_names = list(pr_hcu_crim.keys())
# pr_hcu_crim_values = list(pr_hcu_crim.values())
# pr_hcu_for_names = list(pr_hcu_for.keys())
# pr_hcu_for_values = list(pr_hcu_for.values())
# pr_hcu_not_names = list(pr_hcu_not.keys())
# pr_hcu_not_values = list(pr_hcu_not.values())
# pr_hcu_pcif_names = list(pr_hcu_pcif.keys())
# pr_hcu_pcif_values = list(pr_hcu_pcif.values())
# pr_hcu_reg_names = list(pr_hcu_reg.keys())
# pr_hcu_reg_values = list(pr_hcu_reg.values())
# pr_hcu_cpr_names = list(pr_hcu_cpr.keys())
# pr_hcu_cpr_values = list(pr_hcu_cpr.values())

# %%
def plot_it(l,b):
    ihc_val = 0
    if "c" in l:
        ihc_val = 1
        if "h" in l:
            ihc_val = 3
    else:
        ihc_val = 0
        if "h" in l:
            ihc_val = 2
                
    if "u" in l:
        ue_val = 1
    else:
        ue_val = 0
    print("axs["+str(ue_val)+","+str(ihc_val)+"].plot(pr_"+l+"_"+b+"_names, pr_"+l+"_"+b+"_values)")
    
def print_title(l,b):
    ihc_val = 0
    if "c" in l:
        ihc_val = 1
        if "h" in l:
            ihc_val = 3
    else:
        ihc_val = 0
        if "h" in l:
            ihc_val = 2
                
    if "u" in l:
        ue_val = 1
    else:
        ue_val = 0
        
    ihc_status = 'No PCI/PHI'
    if "c" in l:
        ihc_status = 'PCI'
        if "h" in l:
            ihc_status = 'PCI & PHI'
    else:
        ihc_status = 'No PCI/PHI'
        if "h" in l:
            ihc_status = 'PHI'
    
    eu_status = 'E'
    if "u" in l:
        eu_status = 'C/E'
    else:
        eu_status = 'E'
        
    print("axs["+str(ue_val)+","+str(ihc_val)+"].set_title('"+ihc_status+"', '"+eu_status+"')")
            
for x in lvls:
    for y in blvls:
        plot_it(x,y)
    print_title(x,y)
# Out:
# axs[0,0].plot(pr_ie_bc_names, pr_ie_bc_values)
# axs[0,0].plot(pr_ie_cc_names, pr_ie_cc_values)
# axs[0,0].plot(pr_ie_cafd_names, pr_ie_cafd_values)
# axs[0,0].plot(pr_ie_crem_names, pr_ie_crem_values)
# axs[0,0].plot(pr_ie_crim_names, pr_ie_crim_values)
# axs[0,0].plot(pr_ie_for_names, pr_ie_for_values)
# axs[0,0].plot(pr_ie_not_names, pr_ie_not_values)
# axs[0,0].plot(pr_ie_pcif_names, pr_ie_pcif_values)
# axs[0,0].plot(pr_ie_reg_names, pr_ie_reg_values)
# axs[0,0].plot(pr_ie_cpr_names, pr_ie_cpr_values)
# axs[0,0].set_title('No PCI/PHI', 'E')
# axs[1,0].plot(pr_iu_bc_names, pr_iu_bc_values)
# axs[1,0].plot(pr_iu_cc_names, pr_iu_cc_values)
# axs[1,0].plot(pr_iu_cafd_names, pr_iu_cafd_values)
# axs[1,0].plot(pr_iu_crem_names, pr_iu_crem_values)
# axs[1,0].plot(pr_iu_crim_names, pr_iu_crim_values)
# axs[1,0].plot(pr_iu_for_names, pr_iu_for_values)
# axs[1,0].plot(pr_iu_not_names, pr_iu_not_values)
# axs[1,0].plot(pr_iu_pcif_names, pr_iu_pcif_values)
# axs[1,0].plot(pr_iu_reg_names, pr_iu_reg_values)
# axs[1,0].plot(pr_iu_cpr_names, pr_iu_cpr_values)
# axs[1,0].set_title('No PCI/PHI', 'C/E')
# axs[0,2].plot(pr_he_bc_names, pr_he_bc_values)
# axs[0,2].plot(pr_he_cc_names, pr_he_cc_values)
# axs[0,2].plot(pr_he_cafd_names, pr_he_cafd_values)
# axs[0,2].plot(pr_he_crem_names, pr_he_crem_values)
# axs[0,2].plot(pr_he_crim_names, pr_he_crim_values)
# axs[0,2].plot(pr_he_for_names, pr_he_for_values)
# axs[0,2].plot(pr_he_not_names, pr_he_not_values)
# axs[0,2].plot(pr_he_pcif_names, pr_he_pcif_values)
# axs[0,2].plot(pr_he_reg_names, pr_he_reg_values)
# axs[0,2].plot(pr_he_cpr_names, pr_he_cpr_values)
# axs[0,2].set_title('PHI', 'E')
# axs[1,2].plot(pr_hu_bc_names, pr_hu_bc_values)
# axs[1,2].plot(pr_hu_cc_names, pr_hu_cc_values)
# axs[1,2].plot(pr_hu_cafd_names, pr_hu_cafd_values)
# axs[1,2].plot(pr_hu_crem_names, pr_hu_crem_values)
# axs[1,2].plot(pr_hu_crim_names, pr_hu_crim_values)
# axs[1,2].plot(pr_hu_for_names, pr_hu_for_values)
# axs[1,2].plot(pr_hu_not_names, pr_hu_not_values)
# axs[1,2].plot(pr_hu_pcif_names, pr_hu_pcif_values)
# axs[1,2].plot(pr_hu_reg_names, pr_hu_reg_values)
# axs[1,2].plot(pr_hu_cpr_names, pr_hu_cpr_values)
# axs[1,2].set_title('PHI', 'C/E')
# axs[0,1].plot(pr_ce_bc_names, pr_ce_bc_values)
# axs[0,1].plot(pr_ce_cc_names, pr_ce_cc_values)
# axs[0,1].plot(pr_ce_cafd_names, pr_ce_cafd_values)
# axs[0,1].plot(pr_ce_crem_names, pr_ce_crem_values)
# axs[0,1].plot(pr_ce_crim_names, pr_ce_crim_values)
# axs[0,1].plot(pr_ce_for_names, pr_ce_for_values)
# axs[0,1].plot(pr_ce_not_names, pr_ce_not_values)
# axs[0,1].plot(pr_ce_pcif_names, pr_ce_pcif_values)
# axs[0,1].plot(pr_ce_reg_names, pr_ce_reg_values)
# axs[0,1].plot(pr_ce_cpr_names, pr_ce_cpr_values)
# axs[0,1].set_title('PCI', 'E')
# axs[1,1].plot(pr_cu_bc_names, pr_cu_bc_values)
# axs[1,1].plot(pr_cu_cc_names, pr_cu_cc_values)
# axs[1,1].plot(pr_cu_cafd_names, pr_cu_cafd_values)
# axs[1,1].plot(pr_cu_crem_names, pr_cu_crem_values)
# axs[1,1].plot(pr_cu_crim_names, pr_cu_crim_values)
# axs[1,1].plot(pr_cu_for_names, pr_cu_for_values)
# axs[1,1].plot(pr_cu_not_names, pr_cu_not_values)
# axs[1,1].plot(pr_cu_pcif_names, pr_cu_pcif_values)
# axs[1,1].plot(pr_cu_reg_names, pr_cu_reg_values)
# axs[1,1].plot(pr_cu_cpr_names, pr_cu_cpr_values)
# axs[1,1].set_title('PCI', 'C/E')
# axs[0,3].plot(pr_hce_bc_names, pr_hce_bc_values)
# axs[0,3].plot(pr_hce_cc_names, pr_hce_cc_values)
# axs[0,3].plot(pr_hce_cafd_names, pr_hce_cafd_values)
# axs[0,3].plot(pr_hce_crem_names, pr_hce_crem_values)
# axs[0,3].plot(pr_hce_crim_names, pr_hce_crim_values)
# axs[0,3].plot(pr_hce_for_names, pr_hce_for_values)
# axs[0,3].plot(pr_hce_not_names, pr_hce_not_values)
# axs[0,3].plot(pr_hce_pcif_names, pr_hce_pcif_values)
# axs[0,3].plot(pr_hce_reg_names, pr_hce_reg_values)
# axs[0,3].plot(pr_hce_cpr_names, pr_hce_cpr_values)
# axs[0,3].set_title('PCI & PHI', 'E')
# axs[1,3].plot(pr_hcu_bc_names, pr_hcu_bc_values)
# axs[1,3].plot(pr_hcu_cc_names, pr_hcu_cc_values)
# axs[1,3].plot(pr_hcu_cafd_names, pr_hcu_cafd_values)
# axs[1,3].plot(pr_hcu_crem_names, pr_hcu_crem_values)
# axs[1,3].plot(pr_hcu_crim_names, pr_hcu_crim_values)
# axs[1,3].plot(pr_hcu_for_names, pr_hcu_for_values)
# axs[1,3].plot(pr_hcu_not_names, pr_hcu_not_values)
# axs[1,3].plot(pr_hcu_pcif_names, pr_hcu_pcif_values)
# axs[1,3].plot(pr_hcu_reg_names, pr_hcu_reg_values)
# axs[1,3].plot(pr_hcu_cpr_names, pr_hcu_cpr_values)
# axs[1,3].set_title('PCI & PHI', 'C/E')

# %%
import matplotlib.pyplot as plt


fig, axs = plt.subplots(2,4, figsize=(15, 8), sharey=True)



axs[0,0].plot(pr_ie_bc_names, pr_ie_bc_values)
axs[0,0].plot(pr_ie_cc_names, pr_ie_cc_values)
axs[0,0].plot(pr_ie_cafd_names, pr_ie_cafd_values)
axs[0,0].plot(pr_ie_crem_names, pr_ie_crem_values)
axs[0,0].plot(pr_ie_crim_names, pr_ie_crim_values)
axs[0,0].plot(pr_ie_for_names, pr_ie_for_values)
axs[0,0].plot(pr_ie_not_names, pr_ie_not_values)
axs[0,0].plot(pr_ie_pcif_names, pr_ie_pcif_values)
axs[0,0].plot(pr_ie_reg_names, pr_ie_reg_values)
axs[0,0].plot(pr_ie_cpr_names, pr_ie_cpr_values)
axs[0,0].set_title('No PCI/PHI, E')
axs[1,0].plot(pr_iu_bc_names, pr_iu_bc_values)
axs[1,0].plot(pr_iu_cc_names, pr_iu_cc_values)
axs[1,0].plot(pr_iu_cafd_names, pr_iu_cafd_values)
axs[1,0].plot(pr_iu_crem_names, pr_iu_crem_values)
axs[1,0].plot(pr_iu_crim_names, pr_iu_crim_values)
axs[1,0].plot(pr_iu_for_names, pr_iu_for_values)
axs[1,0].plot(pr_iu_not_names, pr_iu_not_values)
axs[1,0].plot(pr_iu_pcif_names, pr_iu_pcif_values)
axs[1,0].plot(pr_iu_reg_names, pr_iu_reg_values)
axs[1,0].plot(pr_iu_cpr_names, pr_iu_cpr_values)
axs[1,0].set_title('No PCI/PHI, C/E')
axs[0,2].plot(pr_he_bc_names, pr_he_bc_values)
axs[0,2].plot(pr_he_cc_names, pr_he_cc_values)
axs[0,2].plot(pr_he_cafd_names, pr_he_cafd_values)
axs[0,2].plot(pr_he_crem_names, pr_he_crem_values)
axs[0,2].plot(pr_he_crim_names, pr_he_crim_values)
axs[0,2].plot(pr_he_for_names, pr_he_for_values)
axs[0,2].plot(pr_he_not_names, pr_he_not_values)
axs[0,2].plot(pr_he_pcif_names, pr_he_pcif_values)
axs[0,2].plot(pr_he_reg_names, pr_he_reg_values)
axs[0,2].plot(pr_he_cpr_names, pr_he_cpr_values)
axs[0,2].set_title('PHI, E')
axs[1,2].plot(pr_hu_bc_names, pr_hu_bc_values)
axs[1,2].plot(pr_hu_cc_names, pr_hu_cc_values)
axs[1,2].plot(pr_hu_cafd_names, pr_hu_cafd_values)
axs[1,2].plot(pr_hu_crem_names, pr_hu_crem_values)
axs[1,2].plot(pr_hu_crim_names, pr_hu_crim_values)
axs[1,2].plot(pr_hu_for_names, pr_hu_for_values)
axs[1,2].plot(pr_hu_not_names, pr_hu_not_values)
axs[1,2].plot(pr_hu_pcif_names, pr_hu_pcif_values)
axs[1,2].plot(pr_hu_reg_names, pr_hu_reg_values)
axs[1,2].plot(pr_hu_cpr_names, pr_hu_cpr_values)
axs[1,2].set_title('PHI, C/E')
axs[0,1].plot(pr_ce_bc_names, pr_ce_bc_values)
axs[0,1].plot(pr_ce_cc_names, pr_ce_cc_values)
axs[0,1].plot(pr_ce_cafd_names, pr_ce_cafd_values)
axs[0,1].plot(pr_ce_crem_names, pr_ce_crem_values)
axs[0,1].plot(pr_ce_crim_names, pr_ce_crim_values)
axs[0,1].plot(pr_ce_for_names, pr_ce_for_values)
axs[0,1].plot(pr_ce_not_names, pr_ce_not_values)
axs[0,1].plot(pr_ce_pcif_names, pr_ce_pcif_values)
axs[0,1].plot(pr_ce_reg_names, pr_ce_reg_values)
axs[0,1].plot(pr_ce_cpr_names, pr_ce_cpr_values)
axs[0,1].set_title('PCI, E')
axs[1,1].plot(pr_cu_bc_names, pr_cu_bc_values)
axs[1,1].plot(pr_cu_cc_names, pr_cu_cc_values)
axs[1,1].plot(pr_cu_cafd_names, pr_cu_cafd_values)
axs[1,1].plot(pr_cu_crem_names, pr_cu_crem_values)
axs[1,1].plot(pr_cu_crim_names, pr_cu_crim_values)
axs[1,1].plot(pr_cu_for_names, pr_cu_for_values)
axs[1,1].plot(pr_cu_not_names, pr_cu_not_values)
axs[1,1].plot(pr_cu_pcif_names, pr_cu_pcif_values)
axs[1,1].plot(pr_cu_reg_names, pr_cu_reg_values)
axs[1,1].plot(pr_cu_cpr_names, pr_cu_cpr_values)
axs[1,1].set_title('PCI, C/E')
axs[0,3].plot(pr_hce_bc_names, pr_hce_bc_values)
axs[0,3].plot(pr_hce_cc_names, pr_hce_cc_values)
axs[0,3].plot(pr_hce_cafd_names, pr_hce_cafd_values)
axs[0,3].plot(pr_hce_crem_names, pr_hce_crem_values)
axs[0,3].plot(pr_hce_crim_names, pr_hce_crim_values)
axs[0,3].plot(pr_hce_for_names, pr_hce_for_values)
axs[0,3].plot(pr_hce_not_names, pr_hce_not_values)
axs[0,3].plot(pr_hce_pcif_names, pr_hce_pcif_values)
axs[0,3].plot(pr_hce_reg_names, pr_hce_reg_values)
axs[0,3].plot(pr_hce_cpr_names, pr_hce_cpr_values)
axs[0,3].set_title('PCI & PHI, E')
axs[1,3].plot(pr_hcu_bc_names, pr_hcu_bc_values)
axs[1,3].plot(pr_hcu_cc_names, pr_hcu_cc_values)
axs[1,3].plot(pr_hcu_cafd_names, pr_hcu_cafd_values)
axs[1,3].plot(pr_hcu_crem_names, pr_hcu_crem_values)
axs[1,3].plot(pr_hcu_crim_names, pr_hcu_crim_values)
axs[1,3].plot(pr_hcu_for_names, pr_hcu_for_values)
axs[1,3].plot(pr_hcu_not_names, pr_hcu_not_values)
axs[1,3].plot(pr_hcu_pcif_names, pr_hcu_pcif_values)
axs[1,3].plot(pr_hcu_reg_names, pr_hcu_reg_values)
axs[1,3].plot(pr_hcu_cpr_names, pr_hcu_cpr_values)
axs[1,3].set_title('PCI & PHI, C/E')

fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5,0.98,'Categorical Plotting')
